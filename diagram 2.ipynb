# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from pydataset import data

# %%
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
df=data('attitude')

# %%
df
# Out:
#     rating  complaints  privileges  learning  raises  critical  advance
# 1       43          51          30        39      61        92       45
# 2       63          64          51        54      63        73       47
# 3       71          70          68        69      76        86       48
# 4       61          63          45        47      54        84       35
# 5       81          78          56        66      71        83       47
# 6       43          55          49        44      54        49       34
# 7       58          67          42        56      66        68       35
# 8       71          75          50        55      70        66       41
# 9       72          82          72        67      71        83       31
# 10      67          61          45        47      62        80       41
# 11      64          53          53        58      58        67       34
# 12      67          60          47        39      59        74       41
# ...

# %% [markdown]
# ### Box Plot

# %%
df
# Out:
#     rating  complaints  privileges  learning  raises  critical  advance
# 1       43          51          30        39      61        92       45
# 2       63          64          51        54      63        73       47
# 3       71          70          68        69      76        86       48
# 4       61          63          45        47      54        84       35
# 5       81          78          56        66      71        83       47
# 6       43          55          49        44      54        49       34
# 7       58          67          42        56      66        68       35
# 8       71          75          50        55      70        66       41
# 9       72          82          72        67      71        83       31
# 10      67          61          45        47      62        80       41
# 11      64          53          53        58      58        67       34
# 12      67          60          47        39      59        74       41
# ...

# %%
heat_map = df.corr()
sns.heatmap(heat_map)
plt.show()

# %% [markdown]
# ### HISPLOT

# %%
sns.histplot(df.rating)
plt.show()

# %% [markdown]
# ### LINEPLOT

# %%
df
# Out:
#     rating  complaints  privileges  learning  raises  critical  advance
# 1       43          51          30        39      61        92       45
# 2       63          64          51        54      63        73       47
# 3       71          70          68        69      76        86       48
# 4       61          63          45        47      54        84       35
# 5       81          78          56        66      71        83       47
# 6       43          55          49        44      54        49       34
# 7       58          67          42        56      66        68       35
# 8       71          75          50        55      70        66       41
# 9       72          82          72        67      71        83       31
# 10      67          61          45        47      62        80       41
# 11      64          53          53        58      58        67       34
# 12      67          60          47        39      59        74       41
# ...

# %%
df
# Out:
#     rating  complaints  privileges  learning  raises  critical  advance
# 1       43          51          30        39      61        92       45
# 2       63          64          51        54      63        73       47
# 3       71          70          68        69      76        86       48
# 4       61          63          45        47      54        84       35
# 5       81          78          56        66      71        83       47
# 6       43          55          49        44      54        49       34
# 7       58          67          42        56      66        68       35
# 8       71          75          50        55      70        66       41
# 9       72          82          72        67      71        83       31
# 10      67          61          45        47      62        80       41
# 11      64          53          53        58      58        67       34
# 12      67          60          47        39      59        74       41
# ...

# %% [markdown]
# ### LINE PLOT

# %%
sns.lineplot(color="Green",x='rating',y= 'advance' , data=df)
plt.title("rating vs advance")
plt.show()

# %% [markdown]
# ### PAIR PLOT

# %%
 sns.pairplot(data=df)
plt.show()

# %% [markdown]
# ### BAR PLOT

# %%
plt.figure(figsize=(8,4))
sns.barplot('learning','complaints', data=df)
plt.title("learning & complaints")
plt.show()

# %% [markdown]
# ### FACTOR PLOT

# %%
sns.set_style('ticks')
sns.factorplot('rating', 'complaints', hue='raises',data=df)
plt.show()
