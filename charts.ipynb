# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('./Titanic.csv')
data.sample(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1293         1294       NaN       1
# 480           481       0.0       3
# 56             57       1.0       2
# 655           656       0.0       2
# 126           127       0.0       3
# 265           266       0.0       2
# 42             43       0.0       3
# 868           869       0.0       3
# 1056         1057       NaN       3
# 406           407       0.0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1293              Gibson, Miss. Dorothy Winifred  female  22.0      0      1
# 480               Goodwin, Master. Harold Victor    male   9.0      5      2
# 56                             Rugg, Miss. Emily  female  21.0      0      0
# 655                    Hickman, Mr. Leonard Mark    male  24.0      2      0
# 126                          McMahon, Mr. Martin    male   NaN      0      0
# 265                            Reeves, Mr. David    male  36.0      0      0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
data.shape
# Out:
# (1309, 21)

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
data.sample(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 782           783       0.0       1
# 219           220       0.0       2
# 37             38       0.0       3
# 1102         1103       NaN       3
# 1075         1076       NaN       1
# 767           768       0.0       3
# 175           176       0.0       3
# 937           938       NaN       1
# 76             77       0.0       3
# 995           996       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 782                              Long, Mr. Milton Clyde    male  29.0      0
# 219                                  Harris, Mr. Walter    male  30.0      0
# 37                             Cann, Mr. Ernest Charles    male  21.0      0
# 1102                                  Finoli, Mr. Luigi    male   NaN      0
# 1075  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# 767                                  Mangan, Miss. Mary  female  30.5      0
# ...

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# ### KDE PLOT

# %%
plt.figure(figsize=(4,3))
sns.kdeplot(data=data.PassengerId)
plt.show()

# %% [markdown]
# ### HISPLOT

# %%
sns.histplot(data.Fare)
plt.show()

# %% [markdown]
# ### BOX PLOT

# %%
sns.boxplot(color="Pink",x='Age',data=data)
plt.show()

# %% [markdown]
# ### MULTI VARIATE ANALYSIS

# %% [markdown]
# ### LINE PLOT

# %%
sns.lineplot(color="Red",x='Age',y= 'Fare' , data=data)
plt.title("Age vs Fare")
plt.show()

# %% [markdown]
# ### PIE CHART

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
Pclass_Survived = data.groupby(['Pclass'])['Survived'].sum()

# %%
Pclass_Survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
sns.set_style('ticks')
Pclass_Survived.plot.pie()
plt.legend()
plt.show()

# %%
Pclass_Sex_Survived = data.groupby(['Pclass','Sex'])['Survived'].sum()

# %%
Pclass_Sex_Survived.reset_index()
# Out:
#    Pclass     Sex  Survived
# 0       1  female      91.0
# 1       1    male      45.0
# 2       2  female      70.0
# 3       2    male      17.0
# 4       3  female      72.0
# 5       3    male      47.0

# %%
Pclass_Sex_Survived.plot.pie(autopct = '%1.2f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left', borderaxespad=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### BAR CHART

# %%
plt.figure(figsize=(4,3))
sns.countplot('Sex',hue = 'Survived',data=data)
plt.show()

# %% [markdown]
# ### COUNT PLOT

# %%
plt.figure(figsize=(4,3))
sns.countplot('Survived', data=data)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.set_style('darkgrid')
sns.countplot('Pclass', hue='Survived', data=data)
plt.title('Pclass: Survived vs Dead')
plt.show()

# %% [markdown]
# ### FACTOR PLOT

# %%
sns.set_style('ticks')
sns.factorplot('Pclass', 'Survived', hue='Sex',data=data)
plt.show()

# %% [markdown]
# ### VIOLIN PLOT

# %%
sns.set_style('dark')
plt.figure(figsize=(4,3.5))
sns.violinplot("Sex","Age", hue="Survived", data=data)
plt.show()

# %% [markdown]
# ### BAR PLOT

# %%
+

# %% [markdown]
# ### PAIR PLOT

# %%
sns.pairplot(data=data)
plt.show()

# %% [markdown]
# ### HEAT MAP

# %%
heat_map = data.corr()
sns.heatmap(heat_map)
plt.show()

# %%
plt.figure(figsize=(2,6))
sns.kdeplot(data=data.Fare)
plt.show()

# %%
plt.figure(figsize=(8,2))
sns.barplot('SibSp','PassengerId', data=data)
plt.title("SibSp & PassengerId")
plt.show()

# %%
sns.set_style('dark')
plt.figure(figsize=(6,2.5))
sns.violinplot("Sex","Age", hue="Survived", data=data)
plt.show()

# %%
sns.set_style('ticks')
sns.factorplot('Fare', 'Survived', hue='Sex',data=data)
plt.show()

# %%
sns.set_style('whitegrid')
sns.factorplot('Pclass', 'Survived', hue='Sex',data=data)
plt.show()

# %%
sns.boxplot(color="green",x='Age',data=data)
plt.show()

# %%
# Out:
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_4460\2456326658.py", line 1
#     Pclass_Sex_female = data.groupby(['Pclass','female'].sum()
#                                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.figure(figsize=(6,2))
sns.kdeplot(data=data.Fare)
plt.show()

# %%
sns.histplot(data.)
plt.show()
