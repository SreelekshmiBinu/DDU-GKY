# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
x=[3,4,5,6]

# %%
x
# Out:
# [3, 4, 5, 6]

# %%
y=[5,7,4,8]

# %%
y
# Out:
# [5, 7, 4, 8]

# %%
plt.plot(x,y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
# Out:
# Text(0, 0.5, 'y - axis')
